# %%
# !pip install filesplit
# Out:
# ...
#   Created wheel for filesplit: filename=filesplit-3.0.2-cp37-none-any.whl size=4937 sha256=449629e1182663aea9b989991f34b7a3e785c46c2c0cbe58654fcd4961a8a718
#   Stored in directory: /root/.cache/pip/wheels/63/d3/e6/a8d9d330304987156993af1d5120c9840ccfe714dc122ebf07
# Successfully built filesplit
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
db_dir = '/content/drive/My Drive/f1ml/db/'

# %%
from fsplit.filesplit import Filesplit

fs = Filesplit()

# %%
fs.split(file="/content/drive/My Drive/f1ml/sd/47.1-5-loss-0.07.pth", split_size=70000000, output_dir="/content/drive/My Drive/f1ml/model_split_47")

# %%
fs.merge(input_dir="/content/drive/My Drive/f1ml/model_split",output_file="/content/drive/My Drive/f1ml/model_sd.pth", cleanup=False)
